# %% [markdown]
# # Automated scoring

# %%
import os
import random
import json
import requests
import csv
from sightengine.client import SightengineClient

import os
import random
import json
import requests
import csv
from sightengine.client import SightengineClient

imgs = os.listdir("../data")
maleSpeakers = []
femaleSpeaker = []
finalImgList = []
scored = []

haystackKeys = [
        {'key': 'dc82c82ad007c32c543169d8485a0315', 'from': 0, 'until': 20},
        {'key': '3599015fbecf4ef7539cc6e6309ac025','from': 20, 'until': 40},
        {'key': '','from': 40, 'until': 60},
        {'key': '','from': 60, 'until': 80},
        {'key': '','from': 80, 'until': 101}]

sightengineKeys = [
    {'user': '452881799', 'password': 'qWLsshRNM3xRSwaYDvf3', 'from': 0, 'until': int(len(imgs) /2) },
    {'user': '425954127', 'password': 'r3fZbHs6RjgVcrAwbYRi', 'from': int(len(imgs) /2) + 1, 'until': len(imgs) } ]


for key in range (0, len(sightengineKeys)):
    client = SightengineClient(sightengineKeys[key]["user"], sightengineKeys[key]["password"])
    for i in range(sightengineKeys[key]["from"], sightengineKeys[key]["until"]):
        print("detecting gender...", i, "/", len(imgs), imgs[i])
        try:
            output = client.check('face-attributes').set_file("../data/" + imgs[i])
            femalescore = output["faces"][0]["attributes"]["female"]
            malescore = output["faces"][0]["attributes"]["male"]
        except:
            print("something went wrong")  
            continue
        if(femalescore >  malescore): femaleSpeaker.append(imgs[i])
        else: maleSpeakers.append(imgs[i])
# Out:
# detecting gender... 0 / 904 409465099.jpg
# detecting gender... 1 / 904 158943747.png
# detecting gender... 2 / 904 880912428.png
# detecting gender... 3 / 904 Chris Jurney.jpg
# detecting gender... 4 / 904 394699230.jpg
# detecting gender... 5 / 904 116573070.jpg
# detecting gender... 6 / 904 229431596.jpg
# detecting gender... 7 / 904 373236224.jpg
# detecting gender... 8 / 904 Michael Kearns.jpg
# detecting gender... 9 / 904 48417056.jpg
# detecting gender... 10 / 904 749276293.jpg
# detecting gender... 11 / 904 143665089.jpg
# detecting gender... 12 / 904 124156658=rbi
# detecting gender... 13 / 904 562772959.png
# detecting gender... 14 / 904 503582536=267
# detecting gender... 15 / 904 410485947.jpg
# detecting gender... 16 / 904 893901295jpeg
# detecting gender... 17 / 904 Lorrie Faith Cranor.png
# detecting gender... 18 / 904 632452835.jpg
# detecting gender... 19 / 904 2855364.png
# detecting gender... 20 / 904 276295318.png
# detecting gender... 21 / 904 32856029.png
# detecting gender... 22 / 904 580364762=rbi
# detecting gender... 23 / 904 Deg Smiling=120
# detecting gender... 24 / 904 496411363=rbi
# detecting gender... 25 / 904 Bob Sottilare.jpg
# detecting gender... 26 / 904 921147724.jpg
# detecting gender... 27 / 904 372747367.jpg
# detecting gender... 28 / 904 667138871.jpg
# detecting gender... 29 / 904 178991389w170
# detecting gender... 30 / 904 295587596.png
# detecting gender... 31 / 904 Picture of Martin Enthed.png
# detecting gender... 32 / 904 746738078.png
# detecting gender... 33 / 904 991718526.jpg
# detecting gender... 34 / 904 123301964.jpg
# detecting gender... 35 / 904 989832397.jpg
# detecting gender... 36 / 904 839297671.jpg
# detecting gender... 37 / 904 Percy Liang.png
# detecting gender... 38 / 904 Frank Fitzek.jpg
# detecting gender... 39 / 904 591930065.png
# detecting gender... 40 / 904 Marie-Christine Rousset.jpg
# detecting gender... 41 / 904 981016039jpeg
# detecting gender... 42 / 904 Chris Jermaine.jpg
# detecting gender... 43 / 904 334818529.png
# detecting gender... 44 / 904 285317139=rbi
# detecting gender... 45 / 904 903763936.png
# detecting gender... 46 / 904 Monica Lam.jpg
# detecting gender... 47 / 904 735448333=rbi
# detecting gender... 48 / 904 Nick Bostrom.jpg
# detecting gender... 49 / 904 840603403=rbi
# detecting gender... 50 / 904 543470210.jpg
# detecting gender... 51 / 904 575449418.jpg
# detecting gender... 52 / 904 Elizabeth F. Churchill.jpg
# detecting gender... 53 / 904 119032865=rbi
# detecting gender... 54 / 904 72058305=rbi
# detecting gender... 55 / 904 881138430.png
# detecting gender... 56 / 904 134892734=rbi
# detecting gender... 57 / 904 806487542.jpg
# detecting gender... 58 / 904 Meik Kottkamp.jpg
# detecting gender... 59 / 904 Kurt Konolige.jpg
# detecting gender... 60 / 904 Peter T. Kirstein.jpg
# detecting gender... 61 / 904 954107770=rbi
# detecting gender... 62 / 904 260299430.png
# detecting gender... 63 / 904 Rudolf Kruse.png
# detecting gender... 64 / 904 Klaus Robert Muller.jpg
# detecting gender... 65 / 904 4127683172000
# detecting gender... 66 / 904 Dario FLoreano.png
# detecting gender... 67 / 904 280022261=rbi
# detecting gender... 68 / 904 Yee Whye Teh.jpg
# detecting gender... 69 / 904 773785911.png
# detecting gender... 70 / 904 760801660.jpg
# detecting gender... 71 / 904 357824694.jpg
# detecting gender... 72 / 904 892167719.jpg
# detecting gender... 73 / 904 878961028=rbi
# detecting gender... 74 / 904 Heinrich Buelthoff.jpg
# detecting gender... 75 / 904 Nick McKeown.jpg
# detecting gender... 76 / 904 Christine Preisach.jpg
# detecting gender... 77 / 904 Bernadette Bouchon Meunier.png
# detecting gender... 78 / 904 982677822.JPG
# detecting gender... 79 / 904 David Hand.jpg
# detecting gender... 80 / 904 Prof. Dr. Henk Corporall.jpg
# detecting gender... 81 / 904 Drew Bagnell.jpg
# detecting gender... 82 / 904 312139418.png
# detecting gender... 83 / 904 455773067jpeg
# detecting gender... 84 / 904 864718698.jpg
# detecting gender... 85 / 904 192384340.png
# detecting gender... 86 / 904 385410795=rbi
# detecting gender... 87 / 904 Marta Kwiatkowska, Oxford.jpg
# detecting gender... 88 / 904 327517625.jpg
# detecting gender... 89 / 904 194928658.png
# detecting gender... 90 / 904 746595416.jpg
# detecting gender... 91 / 904 442500166.jpg
# detecting gender... 92 / 904 littman.jpg
# detecting gender... 93 / 904 421201330=rbi
# detecting gender... 94 / 904 8263415=rbi
# detecting gender... 95 / 904 136434887.jpg
# detecting gender... 96 / 904 416850134=rbi
# detecting gender... 97 / 904 882423561.jpg
# detecting gender... 98 / 904 692516828.png
# detecting gender... 99 / 904 Guy L. Steele Jr.4000
# detecting gender... 100 / 904 391725280=rbi
# detecting gender... 101 / 904 455052790.jpg
# detecting gender... 102 / 904 HTML5 Icon.jpg
# detecting gender... 103 / 904 Jose Principe.png
# detecting gender... 104 / 904 Jeremy Frank.jpg
# detecting gender... 105 / 904 985000804.png
# detecting gender... 106 / 904 Paco Herrera.png
# detecting gender... 107 / 904 606980526=rbi
# detecting gender... 108 / 904 506005383.png
# detecting gender... 109 / 904 110785922=rbi
# detecting gender... 110 / 904 640809050.png
# detecting gender... 111 / 904 251705011.jpg
# detecting gender... 112 / 904 528394903=rbi
# detecting gender... 113 / 904 793653458.jpg
# detecting gender... 114 / 904 825811014.jpg
# detecting gender... 115 / 904 468337067.jpg
# detecting gender... 116 / 904 147964518.jpg
# detecting gender... 117 / 904 375851279.png
# detecting gender... 118 / 904 photo.jpg
# detecting gender... 119 / 904 Andrey Breslav5000
# detecting gender... 120 / 904 796466361=rbi
# detecting gender... 121 / 904 936967605.png
# detecting gender... 122 / 904 359443131.png
# detecting gender... 123 / 904 571092839.jpg
# detecting gender... 124 / 904 294647782=rbi
# detecting gender... 125 / 904 296578742.jpg
# detecting gender... 126 / 904 172078788=rbi
# detecting gender... 127 / 904 Krawczyk.jpg
# detecting gender... 128 / 904 Susan Murphy.jpg
# detecting gender... 129 / 904 Thomas Zeume.jpg
# detecting gender... 130 / 904 907353618.jpg
# detecting gender... 131 / 904 448273856.png
# detecting gender... 132 / 904 Victoria Stodden.jpg
# detecting gender... 133 / 904 529785286.jpg
# detecting gender... 134 / 904 76115903=rbi
# detecting gender... 135 / 904 663121862=rbi
# detecting gender... 136 / 904 557485266.jpg
# detecting gender... 137 / 904 471964415=rbi
# detecting gender... 138 / 904 93389348=rbi
# detecting gender... 139 / 904 262912634=rbi
# detecting gender... 140 / 904 87629711.jpg
# detecting gender... 141 / 904 309718351.jpg
# detecting gender... 142 / 904 890605509.jpg
# detecting gender... 143 / 904 906002967=rbi
# detecting gender... 144 / 904 Johan Bos.jpg
# detecting gender... 145 / 904 797505493.jpg
# detecting gender... 146 / 904 599816528.png
# detecting gender... 147 / 904 Danica.png
# detecting gender... 148 / 904 373566485.jpg
# detecting gender... 149 / 904 471881412=rbi
# detecting gender... 150 / 904 826208281.jpg
# detecting gender... 151 / 904 430987528.jpg
# detecting gender... 152 / 904 423405850=rbi
# detecting gender... 153 / 904 43461292=rbi
# detecting gender... 154 / 904 559283247.jpg
# detecting gender... 155 / 904 Image.jpg
# detecting gender... 156 / 904 813150666.jpg
# detecting gender... 157 / 904 420667784.jpg
# detecting gender... 158 / 904 768422036.jpg
# detecting gender... 159 / 904 chien.jpg
# detecting gender... 160 / 904 604991826.jpg
# detecting gender... 161 / 904 766870783.jpg
# detecting gender... 162 / 904 Dr. Maurice Pemen.jpg
# detecting gender... 163 / 904 446436405.jpg
# detecting gender... 164 / 904 899942826=rbi
# detecting gender... 165 / 904  Ayanna Howard.jpg
# detecting gender... 166 / 904 Julia Hirschberg.jpg
# detecting gender... 167 / 904 133579867=rbi
# detecting gender... 168 / 904 357930883=rbi
# detecting gender... 169 / 904 734221493.jpg
# detecting gender... 170 / 904 822613945.jpg
# detecting gender... 171 / 904 27762045.jpg
# detecting gender... 172 / 904 463996784.jpg
# detecting gender... 173 / 904 191716507=rbi
# detecting gender... 174 / 904 Miguel Nicolelis.png
# detecting gender... 175 / 904 313909920.jpg
# detecting gender... 176 / 904 Michael Zillich.jpg
# detecting gender... 177 / 904 Alvin E. Roth.jpg
# detecting gender... 178 / 904 690513015.jpg
# detecting gender... 179 / 904 ecai-keynote-darwiche.jpg
# detecting gender... 180 / 904 545142641.jpg
# detecting gender... 181 / 904 Elmar Jurgens.png
# detecting gender... 182 / 904 94010513.jpg
# detecting gender... 183 / 904 289307028.jpg
# detecting gender... 184 / 904 393121012=rbi
# detecting gender... 185 / 904 968142435.gif
# something went wrong
# detecting gender... 186 / 904 Karrie Karahalios.jpg
# detecting gender... 187 / 904 378975057.jpg
# detecting gender... 188 / 904 484938604.jpg
# detecting gender... 189 / 904 613606195.jpg
# detecting gender... 190 / 904 920112131=rbi
# detecting gender... 191 / 904 382238964.jpg
# detecting gender... 192 / 904 524099873=rbi
# detecting gender... 193 / 904 282131497.jpg
# detecting gender... 194 / 904 Doug Bowman.jpg
# detecting gender... 195 / 904 980407194.jpg
# detecting gender... 196 / 904 387633936.jpg
# detecting gender... 197 / 904 Gerhard P. Fettweis.jpg
# detecting gender... 198 / 904 615019794.png
# detecting gender... 199 / 904 Andreas Krause.jpg
# detecting gender... 200 / 904 759556974.jpg
# detecting gender... 201 / 904 644969599.jpg
# detecting gender... 202 / 904 778460585=rbi
# detecting gender... 203 / 904 290675714.jpg
# detecting gender... 204 / 904 508059463.jpg
# detecting gender... 205 / 904 816465814.png
# detecting gender... 206 / 904 298691655.png
# detecting gender... 207 / 904 197779739=rbi
# detecting gender... 208 / 904 191428962.jpg
# detecting gender... 209 / 904 781326995=rbi
# detecting gender... 210 / 904 588137193.png
# detecting gender... 211 / 904 717437829.jpg
# detecting gender... 212 / 904 727604029.jpg
# detecting gender... 213 / 904 830318155=rbi
# detecting gender... 214 / 904 325916837.jpg
# detecting gender... 215 / 904 470217995.jpg
# detecting gender... 216 / 904 272921280.png
# detecting gender... 217 / 904 294795049=rbi
# detecting gender... 218 / 904 Meinolf Sellmann.jpg
# detecting gender... 219 / 904 787211080.jpg
# detecting gender... 220 / 904 331086609.png
# detecting gender... 221 / 904 584692146.jpg
# detecting gender... 222 / 904 373234246.png
# detecting gender... 223 / 904 954359850.jpg
# detecting gender... 224 / 904 454714676=rbi
# detecting gender... 225 / 904 702487448.jpg
# detecting gender... 226 / 904 Mengjie-Zhang.png
# detecting gender... 227 / 904 297245235.jpg
# detecting gender... 228 / 904 Gideon Mann.png
# detecting gender... 229 / 904 464223458.png
# detecting gender... 230 / 904 Shrikanth Narayanan.jpg
# detecting gender... 231 / 904 43761180.png
# detecting gender... 232 / 904 Amit Sheth.jpg
# detecting gender... 233 / 904 gabrilovich.jpg
# detecting gender... 234 / 904 750824367.jpg
# detecting gender... 235 / 904 29111304.jpg
# detecting gender... 236 / 904 417484596.png
# detecting gender... 237 / 904 237487469=rbi
# detecting gender... 238 / 904 544699183.jpg
# detecting gender... 239 / 904 Viktor Vafeiadis, MPI-SWS.jpg
# detecting gender... 240 / 904 656710310.jpg
# detecting gender... 241 / 904 David Gunning.jpg
# detecting gender... 242 / 904 768501613.jpg
# detecting gender... 243 / 904 804232713.jpg
# detecting gender... 244 / 904 Peter Gromov.jpg
# detecting gender... 245 / 904 Sarit Kraus.jpg
# detecting gender... 246 / 904 136276570.jpg
# detecting gender... 247 / 904 155633343=rbi
# detecting gender... 248 / 904 Sean McDirmid5000
# detecting gender... 249 / 904 642340527=rbi
# detecting gender... 250 / 904 252511767.jpg
# detecting gender... 251 / 904 471304401=rbi
# detecting gender... 252 / 904 Vanessa Evers.jpg
# detecting gender... 253 / 904 165919342=rbi
# detecting gender... 254 / 904 579755626.jpg
# detecting gender... 255 / 904 811138379.jpg
# detecting gender... 256 / 904 Wen Tong.jpg
# detecting gender... 257 / 904 Naveen Rao.jpg
# detecting gender... 258 / 904 Steve Young.jpg
# detecting gender... 259 / 904 445318141.jpg
# detecting gender... 260 / 904 93939243.jpg
# detecting gender... 261 / 904 891315347=rbi
# detecting gender... 262 / 904 Ibrahim Gedeon.jpg
# detecting gender... 263 / 904 231009958.jpg
# detecting gender... 264 / 904 369568776.jpg
# detecting gender... 265 / 904 591628965.jpg
# detecting gender... 266 / 904 Zoubin Ghahramani.png
# detecting gender... 267 / 904 Naftali Tishby.png
# detecting gender... 268 / 904 386957036.jpg
# detecting gender... 269 / 904 foto-lluis.jpg
# detecting gender... 270 / 904 88017852.jpg
# detecting gender... 271 / 904 Stephen F. Smith.jpg
# detecting gender... 272 / 904 442790073.png
# detecting gender... 273 / 904 Rector Wei Zhaojpeg
# detecting gender... 274 / 904 773567785.jpg
# detecting gender... 275 / 904 593320594.jpg
# detecting gender... 276 / 904 Mayur Naik8000
# detecting gender... 277 / 904 Daniel Kline.jpg
# detecting gender... 278 / 904 126850248=rbi
# detecting gender... 279 / 904 30187338=rbi
# detecting gender... 280 / 904 921401461.jpg
# detecting gender... 281 / 904 702220830.jpg
# detecting gender... 282 / 904 647040681.jpg
# detecting gender... 283 / 904 846570285=rbi
# detecting gender... 284 / 904 134489531.jpg
# detecting gender... 285 / 904 64812843.png
# detecting gender... 286 / 904 93800384=rbi
# detecting gender... 287 / 904 Peter Dayan.jpg
# something went wrong
# detecting gender... 288 / 904 230679980.jpg
# detecting gender... 289 / 904 Steve Crane.jpg
# detecting gender... 290 / 904 Alice Smith.png
# detecting gender... 291 / 904 Sue Gardner.png
# detecting gender... 292 / 904 svetha-photo.jpg
# detecting gender... 293 / 904 779362932=rbi
# detecting gender... 294 / 904 417589315=rbi
# detecting gender... 295 / 904 22073285.jpg
# detecting gender... 296 / 904 146554757.jpg
# detecting gender... 297 / 904 29786243.jpg
# detecting gender... 298 / 904 86504228.jpg
# detecting gender... 299 / 904 707543519.png
# detecting gender... 300 / 904 Nada Lavracjpeg
# detecting gender... 301 / 904 631568561.jpg
# detecting gender... 302 / 904 Photo of Michael Curran.png
# detecting gender... 303 / 904 513006469.png
# detecting gender... 304 / 904 568851305jpeg
# detecting gender... 305 / 904 Michael Bowling.jpg
# detecting gender... 306 / 904 105159699.png
# detecting gender... 307 / 904 382310467.jpg
# detecting gender... 308 / 904 Frank Leymann.jpg
# detecting gender... 309 / 904 152751529=rbi
# detecting gender... 310 / 904 847847432.jpg
# detecting gender... 311 / 904 399507225.png
# detecting gender... 312 / 904 696101792=125
# detecting gender... 313 / 904 96675889.jpg
# detecting gender... 314 / 904 532563887.jpg
# detecting gender... 315 / 904 705411736.jpg
# detecting gender... 316 / 904 Ian Horrocks.jpg
# detecting gender... 317 / 904 382562136.jpg
# detecting gender... 318 / 904 936152645.png
# detecting gender... 319 / 904 678433024.png
# detecting gender... 320 / 904 633196165.jpg
# detecting gender... 321 / 904 MIkael Wiberg.jpg
# detecting gender... 322 / 904 80190202.png
# detecting gender... 323 / 904 160303649=rbi
# detecting gender... 324 / 904 440729790.png
# detecting gender... 325 / 904 Ramon Lopez de Mantaras.jpg
# detecting gender... 326 / 904 481152056.png
# detecting gender... 327 / 904 Marsha Chechik3000
# detecting gender... 328 / 904 Patrick Le Callet.jpg
# detecting gender... 329 / 904 302761147.jpg
# detecting gender... 330 / 904 Alex Acero.jpg
# detecting gender... 331 / 904 Picture of Anders Ynnerman.jpg
# detecting gender... 332 / 904 894520568=rbi
# detecting gender... 333 / 904 115382696.png
# detecting gender... 334 / 904 363582046jpeg
# detecting gender... 335 / 904 306251874=rbi
# detecting gender... 336 / 904 90415501.jpg
# detecting gender... 337 / 904 Boris Babenko.jpg
# detecting gender... 338 / 904 237158451.png
# detecting gender... 339 / 904 911613700.png
# detecting gender... 340 / 904 Photo of M. Luck.jpg
# detecting gender... 341 / 904 828982922.jpg
# detecting gender... 342 / 904 Heather Miller5000
# detecting gender... 343 / 904 831829606=rbi
# detecting gender... 344 / 904 85549417.jpg
# detecting gender... 345 / 904 899692592=rbi
# detecting gender... 346 / 904 Luciano Floridi.png
# detecting gender... 347 / 904 863655198.JPG
# detecting gender... 348 / 904 755562308=rbi
# detecting gender... 349 / 904 Tucker Taft3000
# detecting gender... 350 / 904 414234664.png
# detecting gender... 351 / 904 109702689.png
# detecting gender... 352 / 904 435947954=rbi
# detecting gender... 353 / 904 857184855.jpg
# detecting gender... 354 / 904 Naoko Yamazakiplay
# something went wrong
# detecting gender... 355 / 904 860259294.jpg
# detecting gender... 356 / 904 23070818.jpg
# detecting gender... 357 / 904 104238461=rbi
# detecting gender... 358 / 904 531999947.jpg
# detecting gender... 359 / 904 115614425.png
# detecting gender... 360 / 904 Guru Parulkar.jpg
# detecting gender... 361 / 904 152960230.jpg
# detecting gender... 362 / 904 917733579.jpg
# detecting gender... 363 / 904 96560831=rbi
# detecting gender... 364 / 904 222133949.jpg
# detecting gender... 365 / 904 Joseph Halpern.png
# detecting gender... 366 / 904 162191023=rbi
# detecting gender... 367 / 904 945745440.jpg
# detecting gender... 368 / 904 Yejin Choi.jpg
# detecting gender... 369 / 904 932845378.jpg
# detecting gender... 370 / 904 Sarah Nadi2000
# detecting gender... 371 / 904 Robert Zubek.jpg
# detecting gender... 372 / 904 669406784.jpg
# detecting gender... 373 / 904 Cristiano Castelfranchi.jpg
# detecting gender... 374 / 904 757048867.png
# detecting gender... 375 / 904 Sebastian Erdweg7000
# detecting gender... 376 / 904 640646481.jpg
# detecting gender... 377 / 904 798303124.png
# detecting gender... 378 / 904 855503038=rbi
# detecting gender... 379 / 904 Oren Etzioni.jpg
# detecting gender... 380 / 904 265435549=rbi
# detecting gender... 381 / 904 34512492.JPG
# detecting gender... 382 / 904 Paula M. Niedenthal.jpg
# detecting gender... 383 / 904 Jennifer Golbeck.jpg
# detecting gender... 384 / 904 418877080=rbi
# detecting gender... 385 / 904 151329420.png
# detecting gender... 386 / 904 764056684.jpg
# detecting gender... 387 / 904 824881698=rbi
# detecting gender... 388 / 904 579987636=rbi
# detecting gender... 389 / 904 Hideki Hashimoto.jpg
# detecting gender... 390 / 904 621244007=rbi
# detecting gender... 391 / 904 706420506.png
# something went wrong
# detecting gender... 392 / 904 723734644=rbi
# detecting gender... 393 / 904 902115534.jpg
# detecting gender... 394 / 904 David Blei.png
# detecting gender... 395 / 904 379728179.png
# detecting gender... 396 / 904 110903414=rbi
# detecting gender... 397 / 904 Marcus Weldon.jpg
# detecting gender... 398 / 904 617142545.jpg
# detecting gender... 399 / 904 702856185=rbi
# detecting gender... 400 / 904 Kathi Fisler7000
# detecting gender... 401 / 904 517191386.jpg
# detecting gender... 402 / 904 Keith Adams9000
# detecting gender... 403 / 904 17622024.jpg
# detecting gender... 404 / 904 295140310.jpg
# detecting gender... 405 / 904 Ina Schaefer.jpg
# detecting gender... 406 / 904 80074651.png
# detecting gender... 407 / 904 36872127.jpg
# detecting gender... 408 / 904 544707149=rbi
# detecting gender... 409 / 904 462825674.jpg
# detecting gender... 410 / 904 12923101.jpg
# detecting gender... 411 / 904 Photo of Vicky Hanson, ACM.png
# detecting gender... 412 / 904 Jonathan Gratch.jpg
# detecting gender... 413 / 904 First slide.png
# something went wrong
# detecting gender... 414 / 904 22147126.png
# detecting gender... 415 / 904 ecai-keynote-mitchell.jpg
# detecting gender... 416 / 904 379978478.jpg
# detecting gender... 417 / 904 Jose L.Verdegay.png
# detecting gender... 418 / 904 604781345.jpg
# detecting gender... 419 / 904 239146503=rbi
# detecting gender... 420 / 904 Christos Papadimitriou.jpg
# detecting gender... 421 / 904 551396446.jpg
# detecting gender... 422 / 904 Subbarao Kambhampati.jpg
# detecting gender... 423 / 904 619865449=rbi
# detecting gender... 424 / 904 Morgan McGuire.png
# detecting gender... 425 / 904 430753204.png
# detecting gender... 426 / 904 Tim Danford.jpg
# detecting gender... 427 / 904 233490434.jpg
# detecting gender... 428 / 904 David E. Smith.gif
# something went wrong
# detecting gender... 429 / 904 173675616=rbi
# detecting gender... 430 / 904 Fanny Chevalier.jpg
# detecting gender... 431 / 904 Kathleen Fisher6000
# detecting gender... 432 / 904 375280410=rbi
# detecting gender... 433 / 904 513041694=rbi
# detecting gender... 434 / 904 Andrea Tagliasacchi.jpg
# detecting gender... 435 / 904 ecai-keynote-woolridge.jpg
# detecting gender... 436 / 904 257721918.jpg
# detecting gender... 437 / 904 70185045.jpg
# detecting gender... 438 / 904 K.jpg
# detecting gender... 439 / 904 642653888.jpg
# detecting gender... 440 / 904 397100036=rbi
# detecting gender... 441 / 904 229293163.jpg
# detecting gender... 442 / 904 Amal Ahmed1000
# detecting gender... 443 / 904 605604627.jpg
# detecting gender... 444 / 904 Lorenzo Casaccia.jpg
# detecting gender... 445 / 904 Fahim-Kawsar.jpg
# detecting gender... 446 / 904 Gail C Murphy.jpg
# detecting gender... 447 / 904 Petros Maragos.png
# detecting gender... 448 / 904 17382068.png
# detecting gender... 449 / 904 485984937=rbi
# detecting gender... 450 / 904 Dimitra Vergyri.jpg
# detecting gender... 451 / 904 258920753w170
# detecting gender... 453 / 904 988772141.jpg
# detecting gender... 454 / 904 980041856.jpg
# detecting gender... 455 / 904 93079324.jpg
# detecting gender... 456 / 904 560672581.jpg
# detecting gender... 457 / 904 784058063=rbi
# detecting gender... 458 / 904 567974645=rbi
# detecting gender... 459 / 904 496276426.jpg
# detecting gender... 460 / 904 922496226=rbi
# detecting gender... 461 / 904 4412340.jpg
# detecting gender... 462 / 904 336631929=rbi
# detecting gender... 463 / 904 96265151.jpg
# detecting gender... 464 / 904 751538892.jpg
# detecting gender... 465 / 904 168945570.jpg
# detecting gender... 466 / 904 133441667=rbi
# detecting gender... 467 / 904 Matt Brown.jpg
# detecting gender... 468 / 904 Julian Togelius.png
# detecting gender... 469 / 904 585474457.jpg
# detecting gender... 470 / 904 235120091.jpg
# detecting gender... 471 / 904 621565260.jpg
# detecting gender... 472 / 904 5432755442Q==
# detecting gender... 473 / 904 Kathleen M. Carley.jpg
# detecting gender... 474 / 904 947069759.png
# detecting gender... 475 / 904 875516854.jpg
# detecting gender... 476 / 904 522536437.jpg
# detecting gender... 477 / 904 R. Michael Young.jpg
# detecting gender... 478 / 904 Rayid Ghani.jpg
# detecting gender... 479 / 904 241102233=rbi
# detecting gender... 480 / 904 839897074=rbi
# detecting gender... 481 / 904 646086990=rbi
# detecting gender... 482 / 904 Satoshi Matsuoka.jpg
# detecting gender... 483 / 904 348978558.png
# detecting gender... 484 / 904 466512324=rbi
# detecting gender... 485 / 904 Cliff Click1000
# detecting gender... 486 / 904 Senior Photographer.jpg
# detecting gender... 487 / 904 152792513jpeg
# detecting gender... 488 / 904 959116437jpeg
# detecting gender... 489 / 904 718247270=rbi
# detecting gender... 490 / 904 746867745=rbi
# detecting gender... 491 / 904 368402316.jpg
# detecting gender... 492 / 904 Demis Hassabis.jpg
# detecting gender... 493 / 904 Irina-.png
# detecting gender... 494 / 904 750257636.png
# something went wrong
# detecting gender... 495 / 904 741451938=rbi
# detecting gender... 496 / 904 845453882.jpg
# detecting gender... 497 / 904 383163305=rbi
# detecting gender... 498 / 904 53021510.jpg
# detecting gender... 499 / 904 275706847.jpg
# detecting gender... 500 / 904 440322919.jpg
# detecting gender... 501 / 904 837103326=rbi
# detecting gender... 502 / 904 Cynthia Breazeal.jpg
# detecting gender... 503 / 904 Photo of M. Wellman.jpg
# detecting gender... 504 / 904 Chris Hawblitzel, Microsoft Research:.jpg
# detecting gender... 505 / 904 338511541.jpg
# detecting gender... 506 / 904 789210710jpeg
# detecting gender... 507 / 904 442886280.jpg
# detecting gender... 508 / 904 945348518jpeg
# detecting gender... 509 / 904 77643832.jpg
# detecting gender... 510 / 904 Dmitri Dolgov.jpg
# detecting gender... 511 / 904 Jane Cleland-Huang.jpg
# detecting gender... 512 / 904 406099416.jpg
# detecting gender... 513 / 904 Claire Tomlin.jpg
# detecting gender... 514 / 904 967575378.png
# detecting gender... 515 / 904 Frank Tip1000
# detecting gender... 516 / 904 Shiyi Wei5000
# detecting gender... 517 / 904 179265170.jpg
# detecting gender... 518 / 904 474202632.jpg
# detecting gender... 519 / 904 Craig Reynolds.jpg
# detecting gender... 520 / 904 594795655.png
# detecting gender... 521 / 904 38986309w170
# detecting gender... 522 / 904 Photo of I. Couzin.png
# detecting gender... 523 / 904 27833076.jpg
# something went wrong
# detecting gender... 524 / 904 848735340=rbi
# something went wrong
# detecting gender... 525 / 904 Tomas Kalibera6000.jpg
# something went wrong
# detecting gender... 526 / 904 888955433.png
# something went wrong
# detecting gender... 527 / 904 460533848.jpg
# something went wrong
# detecting gender... 528 / 904 163185521.png
# something went wrong
# detecting gender... 529 / 904 860757065=rbi
# something went wrong
# detecting gender... 530 / 904 243091652.jpg
# something went wrong
# detecting gender... 531 / 904 Anders Møller1000
# something went wrong
# detecting gender... 532 / 904 Krzysztof Czarnecki.jpg
# something went wrong
# detecting gender... 533 / 904 24657264.jpg
# something went wrong
# detecting gender... 534 / 904 827403646=rbi
# something went wrong
# detecting gender... 535 / 904 148244850.png
# something went wrong
# detecting gender... 536 / 904 Hinrich Schütze.png
# something went wrong
# detecting gender... 537 / 904 545267638=rbi
# something went wrong
# detecting gender... 538 / 904 916035616.jpg
# something went wrong
# detecting gender... 539 / 904 Andre Carvalho.png
# something went wrong
# detecting gender... 540 / 904 814046441.jpg
# something went wrong
# detecting gender... 541 / 904 59425657.jpg
# something went wrong
# detecting gender... 542 / 904 702986338.jpg
# something went wrong
# detecting gender... 543 / 904 873524702.png
# something went wrong
# detecting gender... 544 / 904 725272046.jpg
# something went wrong
# detecting gender... 545 / 904 611933672.jpg
# something went wrong
# detecting gender... 546 / 904 Image of ACM Distinguished Speaker Elizabeth Churchillpcta
# something went wrong
# detecting gender... 547 / 904 521609025.jpg
# something went wrong
# detecting gender... 548 / 904 363267083.jpg
# something went wrong
# detecting gender... 549 / 904 Lauren McHugh.jpg
# something went wrong
# detecting gender... 550 / 904 Four slide.png
# something went wrong
# detecting gender... 551 / 904 Michael Carbin8000
# something went wrong
# detecting gender... 552 / 904 Sumit Basu.jpg
# something went wrong
# detecting gender... 553 / 904 358998658=rbi
# something went wrong
# detecting gender... 554 / 904 288346231.jpg
# something went wrong
# detecting gender... 555 / 904 Elisa Bertino.jpg
# something went wrong
# detecting gender... 556 / 904 87377957.jpg
# something went wrong
# detecting gender... 557 / 904 687494876=rbi
# something went wrong
# detecting gender... 558 / 904 587523051w170
# something went wrong
# detecting gender... 559 / 904 871665025.jpg
# something went wrong
# detecting gender... 560 / 904 Jun Luo.jpg
# something went wrong
# detecting gender... 561 / 904 47136923.png
# something went wrong
# detecting gender... 562 / 904 667967336w170
# something went wrong
# detecting gender... 563 / 904 197089189.jpg
# something went wrong
# detecting gender... 564 / 904 348388346.png
# something went wrong
# detecting gender... 565 / 904 423136605.jpg
# something went wrong
# detecting gender... 566 / 904 974836221.png
# something went wrong
# detecting gender... 567 / 904 268236484=rbi
# something went wrong
# detecting gender... 568 / 904 688000895.jpg
# something went wrong
# detecting gender... 569 / 904 575914382.jpg
# something went wrong
# detecting gender... 570 / 904 Lionel Briand3000
# something went wrong
# detecting gender... 571 / 904 77317976=rbi
# something went wrong
# detecting gender... 572 / 904 860709647.jpg
# something went wrong
# detecting gender... 573 / 904 704031849.jpg
# something went wrong
# detecting gender... 574 / 904 745837230=rbi
# something went wrong
# detecting gender... 575 / 904 358264341.jpg
# something went wrong
# detecting gender... 576 / 904 Farookh Khadeer Hussain.PNG
# something went wrong
# detecting gender... 577 / 904 135266792.jpg
# something went wrong
# detecting gender... 578 / 904 550285973=rbi
# something went wrong
# detecting gender... 579 / 904 Corina Pasareanu4000
# something went wrong
# detecting gender... 580 / 904 Deborah L. McGuinness.png
# something went wrong
# detecting gender... 581 / 904 703501107=rbi
# something went wrong
# detecting gender... 582 / 904 369725700.jpg
# something went wrong
# detecting gender... 583 / 904 Picture of Shengdong Zhao.jpg
# something went wrong
# detecting gender... 584 / 904 433827119.png
# something went wrong
# detecting gender... 585 / 904 Kavita Bala.jpg
# something went wrong
# detecting gender... 586 / 904 549480646.png
# something went wrong
# detecting gender... 587 / 904 Simon Peyton Jones2000
# something went wrong
# detecting gender... 588 / 904 765462575.jpg
# something went wrong
# detecting gender... 589 / 904 802200082=rbi
# something went wrong
# detecting gender... 590 / 904 561859549=rbi
# something went wrong
# detecting gender... 591 / 904 Natasha Noy.png
# something went wrong
# detecting gender... 592 / 904 Eric Jul7000
# something went wrong
# detecting gender... 593 / 904 My Photograph.jpg
# something went wrong
# detecting gender... 594 / 904 Picture of Fabio Pellacini.jpg
# something went wrong
# detecting gender... 595 / 904 13380182=rbi
# something went wrong
# detecting gender... 596 / 904 james crawford.jpg
# something went wrong
# detecting gender... 597 / 904 661308011.png
# something went wrong
# detecting gender... 598 / 904 Pieter Spronck.jpg
# something went wrong
# detecting gender... 599 / 904 616842096.jpg
# something went wrong
# detecting gender... 600 / 904 833665311.jpg
# something went wrong
# detecting gender... 601 / 904 185656453=144
# something went wrong
# detecting gender... 602 / 904 782973008webp
# something went wrong
# detecting gender... 603 / 904 James Kimery.jpg
# something went wrong
# detecting gender... 604 / 904 589067141.jpg
# something went wrong
# detecting gender... 605 / 904 85716188=rbi
# something went wrong
# detecting gender... 606 / 904 32572378=rbi
# something went wrong
# detecting gender... 607 / 904 17691268=rbi
# something went wrong
# detecting gender... 608 / 904 495290254.jpg
# something went wrong
# detecting gender... 609 / 904 An image; Agostino Dovier.jpg
# something went wrong
# detecting gender... 610 / 904 Sarah Nadi6000
# something went wrong
# detecting gender... 611 / 904 Jan Vitek4000
# something went wrong
# detecting gender... 612 / 904 102960808.png
# something went wrong
# detecting gender... 613 / 904 Ben L. Titzer1000
# something went wrong
# detecting gender... 614 / 904 263663879.jpg
# something went wrong
# detecting gender... 615 / 904 17705697.jpg
# something went wrong
# detecting gender... 616 / 904 Nick Graham.jpg
# something went wrong
# detecting gender... 617 / 904 292093089=rbi
# something went wrong
# detecting gender... 618 / 904 680827175.jpg
# something went wrong
# detecting gender... 619 / 904 Klaus Robert Muller.png
# something went wrong
# detecting gender... 620 / 904 295724655.png
# something went wrong
# detecting gender... 621 / 904 Laurence Tratt0000
# something went wrong
# detecting gender... 622 / 904 883944457=rbi
# something went wrong
# detecting gender... 623 / 904 616373435.png
# something went wrong
# detecting gender... 624 / 904 Marta Kwiatkowska.jpg
# something went wrong
# detecting gender... 625 / 904 Joe Pamer9000
# something went wrong
# detecting gender... 626 / 904 472797839.jpg
# something went wrong
# detecting gender... 627 / 904 736766784.jpg
# something went wrong
# detecting gender... 628 / 904 104730438.jpg
# something went wrong
# detecting gender... 629 / 904 673514726=rbi
# something went wrong
# detecting gender... 630 / 904 18858441.jpg
# something went wrong
# detecting gender... 631 / 904 Christopher Berry.jpg
# something went wrong
# detecting gender... 632 / 904 305434318.jpg
# something went wrong
# detecting gender... 633 / 904 192511106.jpg
# something went wrong
# detecting gender... 634 / 904 299619074.jpg
# something went wrong
# detecting gender... 635 / 904 320272527=rbi
# something went wrong
# detecting gender... 636 / 904 Dr. Ram Kumar Krishnamurthy.jpg
# something went wrong
# detecting gender... 637 / 904 kalyanmoy deb.png
# something went wrong
# detecting gender... 638 / 904 598414332.jpg
# something went wrong
# detecting gender... 639 / 904 304052276.jpg
# something went wrong
# detecting gender... 640 / 904 962449794.jpg
# something went wrong
# detecting gender... 641 / 904 Jim Keller.jpg
# something went wrong
# detecting gender... 642 / 904 65606375.jpg
# something went wrong
# detecting gender... 643 / 904 121440512.jpg
# something went wrong
# detecting gender... 644 / 904 621914357.png
# something went wrong
# detecting gender... 645 / 904 536235010jpeg
# something went wrong
# detecting gender... 646 / 904 Gary-B.-Fogel.png
# something went wrong
# detecting gender... 647 / 904 Michael Bratman3upL
# something went wrong
# detecting gender... 648 / 904 19940320.jpg
# something went wrong
# detecting gender... 649 / 904 Julia Rubin5000
# something went wrong
# detecting gender... 650 / 904 Russ Tedrake.jpg
# something went wrong
# detecting gender... 651 / 904 277276459.png
# something went wrong
# detecting gender... 652 / 904 Ke Yi.jpg
# something went wrong
# detecting gender... 653 / 904 Nuria Oliver.jpg
# something went wrong
# detecting gender... 654 / 904 618929986=rbi
# something went wrong
# detecting gender... 655 / 904 44217354.jpg
# something went wrong
# detecting gender... 656 / 904 190108763.jpg
# something went wrong
# detecting gender... 657 / 904 714119803=rbi
# something went wrong
# detecting gender... 658 / 904 wurman.jpg
# something went wrong
# detecting gender... 659 / 904 64769679=rbi
# something went wrong
# detecting gender... 660 / 904 56055363=rbi
# something went wrong
# detecting gender... 661 / 904 567561007.jpg
# something went wrong
# detecting gender... 662 / 904 773183885.jpg
# something went wrong
# detecting gender... 663 / 904 Johanna Seibt.jpg
# something went wrong
# detecting gender... 664 / 904 843139215.jpg
# something went wrong
# detecting gender... 665 / 904 757901865.jpg
# something went wrong
# detecting gender... 666 / 904 773883125=rbi
# something went wrong
# detecting gender... 667 / 904 DARIO_IZZO_cover.jpg
# something went wrong
# detecting gender... 668 / 904 Gord Kurtenbach.jpg
# something went wrong
# detecting gender... 669 / 904 Zhaohui Wu.png
# something went wrong
# detecting gender... 670 / 904 846902165=rbi
# something went wrong
# detecting gender... 671 / 904 873783272.jpg
# something went wrong
# detecting gender... 672 / 904 15978625.jpg
# something went wrong
# detecting gender... 673 / 904 750102291.png
# something went wrong
# detecting gender... 674 / 904 753920171.jpg
# something went wrong
# detecting gender... 675 / 904 747538768.png
# something went wrong
# detecting gender... 676 / 904 981718795=rbi
# something went wrong
# detecting gender... 677 / 904 Matthias Felleisen4000
# something went wrong
# detecting gender... 678 / 904 78180642.png
# something went wrong
# detecting gender... 679 / 904 Reid G. Smith.jpg
# something went wrong
# detecting gender... 680 / 904 883578925.jpg
# something went wrong
# detecting gender... 681 / 904 975834751=rbi
# something went wrong
# detecting gender... 682 / 904 905878985=rbi
# something went wrong
# detecting gender... 683 / 904 773900223=rbi
# something went wrong
# detecting gender... 684 / 904 Nicholas Matsakis9000
# something went wrong
# detecting gender... 685 / 904 883471643.jpg
# something went wrong
# detecting gender... 686 / 904 635358101.jpg
# something went wrong
# detecting gender... 687 / 904 An image; Holger H. Hoos.jpg
# something went wrong
# detecting gender... 688 / 904 Oliver van Kaick.png
# something went wrong
# detecting gender... 689 / 904 veloso.jpg
# something went wrong
# detecting gender... 690 / 904 Takahiro Hara.png
# something went wrong
# detecting gender... 691 / 904 243987234.jpg
# something went wrong
# detecting gender... 692 / 904 852553=rbi
# something went wrong
# detecting gender... 693 / 904 671481163.jpg
# something went wrong
# detecting gender... 694 / 904 Jason Burgess.jpg
# something went wrong
# detecting gender... 695 / 904 94878406=rbi
# something went wrong
# detecting gender... 696 / 904 Cynthia Dwork.png
# something went wrong
# detecting gender... 697 / 904 322149938.jpg
# something went wrong
# detecting gender... 698 / 904 8330178.jpg
# something went wrong
# detecting gender... 699 / 904 174153999.jpg
# something went wrong
# detecting gender... 700 / 904 An image; Enrico Pontelli.jpg
# something went wrong
# detecting gender... 701 / 904 153598548=rbi
# something went wrong
# detecting gender... 702 / 904 859810235.jpg
# something went wrong
# detecting gender... 703 / 904 446946751=rbi
# something went wrong
# detecting gender... 704 / 904 949402689.jpg
# something went wrong
# detecting gender... 705 / 904 Diego Lopez.jpg
# something went wrong
# detecting gender... 706 / 904 793351471.jpg
# something went wrong
# detecting gender... 707 / 904 907311836=rbi
# something went wrong
# detecting gender... 708 / 904 276617087.png
# something went wrong
# detecting gender... 709 / 904 530464497.jpg
# something went wrong
# detecting gender... 710 / 904 890570574.jpg
# something went wrong
# detecting gender... 711 / 904 28126729.jpg
# something went wrong
# detecting gender... 712 / 904 An image; Mark Wallace.png
# something went wrong
# detecting gender... 713 / 904 Christian Rudder | Photo credit: Victor G. Jeffreys II.png
# something went wrong
# detecting gender... 714 / 904 Christof Koch. Photo Credit – Fatma Imamoglu.jpg
# something went wrong
# detecting gender... 715 / 904 707283936.png
# something went wrong
# detecting gender... 716 / 904 627794208=rbi
# something went wrong
# detecting gender... 717 / 904 133471440=rbi
# something went wrong
# detecting gender... 718 / 904 524778651=rbi
# something went wrong
# detecting gender... 719 / 904 871944907=rbi
# something went wrong
# detecting gender... 720 / 904 179631767.jpg
# something went wrong
# detecting gender... 721 / 904 991179439.jpg
# something went wrong
# detecting gender... 722 / 904 342674222.jpg
# something went wrong
# detecting gender... 723 / 904 Virginia Vassilevska Williams.jpg
# something went wrong
# detecting gender... 724 / 904 483493188.jpg
# something went wrong
# detecting gender... 725 / 904 71903279.jpg
# something went wrong
# detecting gender... 726 / 904 926734678=rbi
# something went wrong
# detecting gender... 727 / 904 468661387=rbi
# something went wrong
# detecting gender... 728 / 904 61792124=rbi
# something went wrong
# detecting gender... 729 / 904 David W. Aha.jpg
# something went wrong
# detecting gender... 730 / 904 233124704.jpg
# something went wrong
# detecting gender... 731 / 904 359595959.png
# something went wrong
# detecting gender... 732 / 904 589989091.jpg
# something went wrong
# detecting gender... 733 / 904 636643061.png
# something went wrong
# detecting gender... 734 / 904 602668145.jpg
# something went wrong
# detecting gender... 735 / 904 307122314.jpg
# something went wrong
# detecting gender... 736 / 904 124756462jpeg
# something went wrong
# detecting gender... 737 / 904 321381230jpeg
# something went wrong
# detecting gender... 738 / 904 775906447=rbi
